# %%
from main import NaverLand
from pathlib import Path

# %%
file_name = 'naverLand(20220309-132731)_preprocessed.db'
db_path = Path().home().joinpath('PycharmProjects','naverLand', 'db', file_name)
nl = NaverLand(db_path)
# Out:
# C:\Users\ajcltm\PycharmProjects\naverLand\db\naverLand(20220309-132731)_preprocessed.db

# %%
nl.query_info(where = 'where dealPrice<price and dealPrice<60000 and dealPrice>55000')
nl.queryInfo[['cityName', 'gu', 'dong', 'articleName', 'dealPrice', 'price', 'pct_change']][25:40]
# Out:
#    cityName   gu  dong       articleName  dealPrice  price  pct_change
# 25      서울시  강서구  내발산동   천우네오젠(663-2) 1동      58000  59000    0.000848
# 26      서울시  강서구  내발산동   천우네오젠(663-2) 1동      58000  59000    0.000848
# 27      서울시  강서구  내발산동   천우네오젠(663-2) 1동      58000  59000    0.000848
# 28      서울시  강서구  내발산동   천우네오젠(663-2) 1동      58000  59000    0.000848
# 29      서울시  강서구   방화동      도시개발2단지 215동      59000  60000   -0.014778
# 30      서울시  강서구   방화동      도시개발2단지 215동      59000  60000   -0.014778
# 31      서울시  강서구   방화동  장미(도시개발1단지) 101동      58000  64000    0.066667
# 32      서울시  강서구   방화동             한미 5동      58000  60000    0.052632
# 33      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
# 34      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
# 35      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
# 36      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
# 37      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
# 38      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
# 39      서울시  관악구   신림동             삼성 1동      58000  60000    0.333333
